# %%
help(object)
# Out:
# Help on class object in module builtins:
#
# class object
#  |  The base class of the class hierarchy.
#  |
#  |  When called, it accepts no arguments and returns a new featureless
#  |  instance that has no instance attributes and cannot be given any.
#  |
#  |  Built-in subclasses:
#  |      async_generator
#  |      BaseException
#  |      builtin_function_or_method
#  |      bytearray
#  |      ... and 109 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __dir__(self, /)
#  |      Default dir() implementation.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Default object formatter.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
# ...

# %%
test = object()
test.__setattr__()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ee4d4f8bb2c0> in <module>
#       1 test = object()
# ----> 2 test.__setattr__()
#
# TypeError:  expected 2 arguments, got 0

# %%
test = object()
test.__setattr__('id', 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-d5617d3c7c1d> in <module>
#       1 test = object()
# ----> 2 test.__setattr__('id', 2)
#
# AttributeError: 'object' object has no attribute 'id'

# %%
class User(object):
    id = None
    first_name = None
    last_name = None
    username = None
    email = None
    password = None
    admin = False

help(locals)
# Out:
# Help on built-in function locals in module builtins:
#
# locals()
#     Return a dictionary containing the current scope's local variables.
#
#     NOTE: Whether or not updates to this dictionary will affect name lookups in
#     the local scope and vice-versa is *implementation dependent* and not
#     covered by any backwards compatibility guarantees.

# %%
User.__getattribute__('email')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e8e693962b1f> in <module>
# ----> 1 User.__getattribute__('email')
#
# TypeError: expected 1 argument, got 0

# %%
myUser = User()
myUser.__getattribute__('email')

# %%
myUser.__setattr__('email', 'sag.arnob@gmail.com')

# %%
myUser.__dir__()
# Out:
# ['email',
#  '__module__',
#  'id',
#  'first_name',
#  'last_name',
#  'username',
#  'password',
#  'admin',
#  '__dict__',
#  '__weakref__',
#  '__doc__',
#  '__repr__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__init__',
#  '__new__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
myUser.__dict__()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-af1aad70b4fe> in <module>
# ----> 1 myUser.__dict__()
#
# TypeError: 'dict' object is not callable

# %%
myUser.__dict__
# Out:
# {'email': 'sag.arnob@gmail.com'}

# %%
myUser.__weakref__

# %%
class User(object):
    id = -1
    first_name = ''
    last_name = ''
    username = ''
    email = ''
    password = ''
    is_admin = False

    def __init__(self, *args, **kwargs):
        for k, v in kwargs.items():
            self.__setattr__(k, v)

    def __str__(self) -> str:
        return f"{self.first_name} {self.last_name}"

myUser = User()

# %%
myUser.__dict__
# Out:
# {}

# %%
myUser = User(id=1, first_name="Sajeed", last_name="Ahmed", username="BloodRiver", email="sag.arnob@gmail.com", password="test", is_admin=False)

myUser.__dict__
# Out:
# {'id': 1,
#  'first_name': 'Sajeed',
#  'last_name': 'Ahmed',
#  'username': 'BloodRiver',
#  'email': 'sag.arnob@gmail.com',
#  'password': 'test',
#  'is_admin': False}

# %%
myUser.__class__
# Out:
# __main__.User

# %%
myUser.__name__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-86eff2ff279f> in <module>
# ----> 1 myUser.__name__
#
# AttributeError: 'User' object has no attribute '__name__'

# %%
myUser.__class__.__name__
# Out:
# 'User'

# %%
class Table(object):
    def __init__(self, *args, **kwargs):
        for k, v in kwargs.items():
            self.__setattr__(k, v)

    def get_data(self) -> tuple:
        db = sql.connect(settings.DATABASE)
        cursor = db.cursor()

        query = f"SELECT * FROM `{self.__class__.__name__.lower()}`"

        cursor.execute(query)
        results = cursor.fetchall()
        cursor.close()
        db.close()
        return results


class User(Table):
    id = -1
    first_name = ''
    last_name = ''
    username = ''
    email = ''
    password = ''
    is_admin = False

    def __str__(self) -> str:
        return f"{self.first_name} {self.last_name}"

# %%
myUser = User()
print(myUser.get_data())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9e0cd3ded529> in <module>
#       1 myUser = User()
# ----> 2 print(myUser.get_data())
#
# <ipython-input-18-057cb28c0600> in get_data(self)
#       5
#       6     def get_data(self) -> tuple:
# ----> 7         db = sql.connect(settings.DATABASE)
#       8         cursor = db.cursor()
#       9
#
# NameError: name 'sql' is not defined

# %%
import sqlite3 as sql

class Table(object):
    def __init__(self, *args, **kwargs):
        for k, v in kwargs.items():
            self.__setattr__(k, v)

    def get_data(self) -> tuple:
        db = sql.connect("db.sqlite3")
        cursor = db.cursor()

        query = f"SELECT * FROM `{self.__class__.__name__.lower()}`"

        cursor.execute(query)
        results = cursor.fetchall()
        cursor.close()
        db.close()
        return results


class User(Table):
    id = -1
    first_name = ''
    last_name = ''
    username = ''
    email = ''
    password = ''
    is_admin = False

    def __str__(self) -> str:
        return f"{self.first_name} {self.last_name}"

myUser = User()
myUser.get_data()
# Out:
# [(1, 'Sajeed', 'Ahmed', 'BloodRiver', 'email', 'password', 0),
#  (2, 'Galib', 'Arnob', 'GalAr', 'email2', 'password2', 0),
#  (3, 'Ikram', 'Patwary', 'IkPa', 'email3', 'password3', 0),
#  (4, 'Sakib', 'Sultan', 'SaSu', 'email4', 'password4', 0),
#  (5, 'Rick', 'Astley', 'RickRoll', 'email5', 'password5', 0),
#  (6, 'Sasuke', 'Uchiha', 'Sharingan', 'email6', 'password6', 0),
#  (7, 'Naruto', 'Uzumaki', 'Rasengan', 'email7', 'password7', 0)]

# %%
import sqlite3 as sql

class Table(object):
    def __init__(self, *args, **kwargs):
        for k, v in kwargs.items():
            self.__setattr__(k, v)

    def get_data(self) -> tuple:
        db = sql.connect("db.sqlite3")
        cursor = db.cursor()

        query = f"SELECT * FROM `{self.__class__.__name__.lower()}`"

        cursor.execute(query)
        results = cursor.fetchall()
        cursor.close()
        db.close()
        return results


class User(Table):
    id = -1
    first_name = 's'
    last_name = 's'
    username = 's'
    email = 's'
    password = 's'
    is_admin = False

    def __str__(self) -> str:
        return f"{self.first_name} {self.last_name}"

myUser = User()
myUser.__dict__
# Out:
# {}

# %%
class User(object):
    id = -1
    first_name = 's'
    last_name = 's'
    username = 's'
    email = 's'
    password = 's'
    is_admin = False

    def __str__(self) -> str:
        return f"{self.first_name} {self.last_name}"

myUser = User()
myUser.__dict__
# Out:
# {}

# %%
myUser

# %%
dir(myUser)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'email',
#  'first_name',
#  'id',
#  'is_admin',
#  'last_name',
#  'password',
#  'username']

# %%
myUser.__getattribute__('first_name')
# Out:
# 's'

# %%
class User(Table):
    id = -1
    first_name = ''
    last_name = ''
    username = ''
    email = ''
    password = ''
    is_admin = False

    def __str__(self) -> str:
        return f"{self.first_name} {self.last_name}"

myUser = User()

# %%
myUser.__getattribute__('username')
# Out:
# ''

# %%
bool(myUser.__getattribute__('username'))
# Out:
# False

# %%
myUser.__getattribute__('usernae')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-09d06e9f22ab> in <module>
# ----> 1 myUser.__getattribute__('usernae')
#
# AttributeError: 'User' object has no attribute 'usernae'
